# %% [markdown]
# # Plot 3D skeleton

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML
import matplotlib.animation as animation

# %%
frame_body1 = [-66.3891, -152.869, 88.6576, 0.649536, -54.5507, -163.9, 96.1445, 0.529114, -66.8266, -87.4536, 86.4138, 0.440918, -78.6396, -143.059, 102.304, 0.580444, -94.0792, -119.368, 112.748, 0.438171, -79.1412, -96.6539, 109.947, 0.360962, -72.6987, -86.6945, 96.8789, 0.400208, -74.6244, -47.4068, 95.1169, 0.477051, -79.2791, -8.69149, 95.2027, 0.626953, -59.8689, -146.451, 70.8555, 0.615234, -45.2335, -120.023, 68.829, 0.633972, -41.6612, -139.578, 84.3403, 0.597351, -60.9544, -88.2128, 75.9486, 0.409058, -60.0156, -51.1494, 68.5443, 0.532959, -59.411, -9.99314, 57.4134, 0.586487, -58.3762, -166.521, 98.1794, 0.267334, -69.3257, -164.235, 97.2076, 0.29425, -55.1469, -167.394, 92.2362, 0.534119, -60.892, -165.971, 83.1436, 0.627258, -67.9365, -2.84635, 108.667, 0.49231, -69.4125, -5.02149, 108.381, 0.451599, -81.5109, -4.13921, 92.3132, 0.55011, -39.9082, -4.07838, 60.5546, 0.506897, -44.5915, -3.81412, 55.1152, 0.499146, -63.3763, -5.07094, 56.2541, 0.514954, -61.3084, -179.781, 93.1384, 0.69165]
frame_body2 = [2.21598, -147.447, -80.386, 0.568359, 13.1587, -159.803, -78.6964, 0.528809, 4.35228, -86.8657, -80.2426, 0.457092, -1.34808, -139.499, -65.1915, 0.566956, 0.18429, -112.792, -58.395, 0.439026, 16.8018, -94.0115, -61.6987, 0.480835, 1.3516, -87.2235, -70.5641, 0.443115, -0.494497, -48.2366, -71.2667, 0.56842, -2.46221, -12.3347, -72.4869, 0.648499, 6.07318, -139.063, -94.9594, 0.576233, 24.6525, -119.249, -99.1173, 0.470642, 29.6434, -138.997, -86.549, 0.529785, 7.35298, -86.5079, -89.9211, 0.437744, 5.2161, -47.099, -89.3181, 0.5448, 3.22455, -11.3267, -88.9359, 0.65564, 10.6371, -162.989, -75.9865, 0.49231, 2.1037, -160.829, -72.527, 0.4021, 11.941, -162.352, -82.4047, 0.389648, 4.54262, -160.219, -88.1563, 0.271057, 14.5535, -4.7673, -67.2221, 0.490234, 7.50556, -4.86828, -65.8922, 0.515198, -5.35742, -7.50167, -74.2468, 0.654114, 18.5516, -5.05764, -84.282, 0.354858, 16.6899, -6.09085, -90.2683, 0.355225, -0.442991, -7.41704, -88.5557, 0.441284, 5.64289, -174.556, -80.9333, 0.591003]
x1 = frame_body1[::4] 
y1 = frame_body1[1::4] 
z1 = frame_body1[2::4]
x2 = frame_body2[::4] 
y2 = frame_body2[1::4] 
z2 = frame_body2[2::4]

# %%
r_arm = [[[c[i] for i in [1, 0, 9, 10, 11]] for c in l] for l in [[x1,y1,z1],[x2,y2,z2]]]
l_arm = [[[c[i] for i in [0, 3, 4, 5]] for c in l] for l in [[x1,y1,z1],[x2,y2,z2]]]
r_leg = [[[c[i] for i in [0, 2, 12, 13, 14, 22, 23, 24]] for c in l] for l in [[x1,y1,z1],[x2,y2,z2]]]
l_leg = [[[c[i] for i in [2, 6, 7, 8, 19, 20, 21]] for c in l] for l in [[x1,y1,z1],[x2,y2,z2]]]
head = [[[c[i] for i in [18, 17, 1, 15, 16]] for c in l] for l in [[x1,y1,z1],[x2,y2,z2]]]

# %%
plt.plot(r_arm[0][2], r_arm[0][1])
plt.plot(l_arm[0][2], l_arm[0][1])
plt.plot(r_leg[0][2], r_leg[0][1])
plt.plot(l_leg[0][2], l_leg[0][1])
plt.plot(head[0][2], head[0][1])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
def init():
    ax.plot(r_arm[0][0], r_arm[0][2], r_arm[0][1])
    ax.plot(l_arm[0][0], l_arm[0][2], l_arm[0][1])
    ax.plot(r_leg[0][0], r_leg[0][2], r_leg[0][1])
    ax.plot(l_leg[0][0], l_leg[0][2], l_leg[0][1])
    ax.plot(head[0][0], head[0][2], head[0][1])
    ax.plot(r_arm[1][0], r_arm[1][2], r_arm[1][1])
    ax.plot(l_arm[1][0], l_arm[1][2], l_arm[1][1])
    ax.plot(r_leg[1][0], r_leg[1][2], r_leg[1][1])
    ax.plot(l_leg[1][0], l_leg[1][2], l_leg[1][1])
    ax.plot(head[1][0], head[1][2], head[1][1])
    
    return fig,

def animate(i):
    ax.view_init(elev=220., azim=3.6*i)
    return fig,

# Animate
ani = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=100, blit=True)    

HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
